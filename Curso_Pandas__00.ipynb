# %% [markdown]
# <a href="https://colab.research.google.com/github/SevenBeauty/Curso-Pandas/blob/main/Curso_Pandas__00.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Primeiro exemplo de manipulação de dados usando Python Pandas
#
# Autor: André Caido Ramos
#
# Data: 6 de fevereiro de 2023

# %%
# Para instalar a lib do Pandas
# !pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (1.3.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.8/dist-packages (from pandas) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)

# %%
# Importando biblioteca Pandas no Python
import pandas as pd

gas_df = pd.read_excel("/content/drive/MyDrive/ca-2021-02.xlsx")

# %%
# Usa o print para ver o dataframe!
print(gas_df)
# Out:
#        Regiao - Sigla Estado - Sigla  Municipio  \
# 0                  NE             AL  ARAPIRACA
# 1                  NE             AL  ARAPIRACA
# 2                  NE             AL  ARAPIRACA
# 3                  NE             AL  ARAPIRACA
# 4                  NE             AL  ARAPIRACA
# ...               ...            ...        ...
# 168404             NE             BA     JEQUIE
# 168405             SE             MG  ITUIUTABA
# 168406             SE             MG  ITUIUTABA
# 168407             SE             MG  ITUIUTABA
# 168408             SE             MG  ITUIUTABA
#
#                                            Revenda      CNPJ da Revenda  \
# 0                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 1                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 2                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 3                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 4                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# ...                                            ...                  ...
# 168404  COMERCIAL DE COMBUSTIVEL CACHOEIRINHA LTDA   28.629.089/0001-79
# 168405           ABC DISTRIBUICAO DE PETROLEO LTDA   13.117.591/0006-38
# 168406           ABC DISTRIBUICAO DE PETROLEO LTDA   13.117.591/0006-38
# 168407           ABC DISTRIBUICAO DE PETROLEO LTDA   13.117.591/0006-38
# 168408           ABC DISTRIBUICAO DE PETROLEO LTDA   13.117.591/0006-38
#
#                                       Nome da Rua Numero Rua Complemento  \
# 0                                  RODOVIA AL 220        105       KM 68
# 1                                  RODOVIA AL 220        105       KM 68
# 2                                  RODOVIA AL 220        105       KM 68
# 3                                  RODOVIA AL 220        105       KM 68
# 4                                  RODOVIA AL 220        105       KM 68
# ...                                           ...        ...         ...
# 168404                  AVENIDA T LOT JD TROPICAL         53         NaN
# 168405  AVENIDA PROFESSOR JOSE VIEIRA DE MENDONCA       2415         NaN
# 168406  AVENIDA PROFESSOR JOSE VIEIRA DE MENDONCA       2415         NaN
# 168407  AVENIDA PROFESSOR JOSE VIEIRA DE MENDONCA       2415         NaN
# 168408  AVENIDA PROFESSOR JOSE VIEIRA DE MENDONCA       2415         NaN
#
#              Bairro        Cep             Produto Data da Coleta  \
# 0       CANAFISTULA  57302-605            GASOLINA     2021-11-01
# 1       CANAFISTULA  57302-605              ETANOL     2021-11-01
# 2       CANAFISTULA  57302-605              DIESEL     2021-11-01
# 3       CANAFISTULA  57302-605  GASOLINA ADITIVADA     2021-11-01
# 4       CANAFISTULA  57302-605          DIESEL S10     2021-11-01
# ...             ...        ...                 ...            ...
# 168404     TROPICAL  45209-130              ETANOL     2021-12-31
# 168405     ALVORADA  38307-113            GASOLINA     2021-12-31
# 168406     ALVORADA  38307-113              ETANOL     2021-12-31
# 168407     ALVORADA  38307-113          DIESEL S10     2021-12-31
# 168408     ALVORADA  38307-113  GASOLINA ADITIVADA     2021-12-31
#
#         Valor de Venda  Valor de Compra Unidade de Medida       Bandeira
# 0                6.799              NaN        R$ / litro  VIBRA ENERGIA
# 1                5.299              NaN        R$ / litro  VIBRA ENERGIA
# 2                5.549              NaN        R$ / litro  VIBRA ENERGIA
# 3                6.899              NaN        R$ / litro  VIBRA ENERGIA
# 4                5.649              NaN        R$ / litro  VIBRA ENERGIA
# ...                ...              ...               ...            ...
# 168404           5.859              NaN        R$ / litro     PETROSERRA
# 168405           6.580              NaN        R$ / litro         BRANCA
# 168406           4.740              NaN        R$ / litro         BRANCA
# 168407           5.448              NaN        R$ / litro         BRANCA
# 168408           6.580              NaN        R$ / litro         BRANCA
#
# [168409 rows x 16 columns]

# %%
# Exibe as primeiras 5 linhas
display(gas_df.head())
# Out:
#   Regiao - Sigla Estado - Sigla  Municipio               Revenda  \
# 0             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 1             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 2             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 3             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 4             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
#
#        CNPJ da Revenda     Nome da Rua Numero Rua Complemento       Bairro  \
# 0   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 1   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 2   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 3   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 4   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
#
#          Cep             Produto Data da Coleta  Valor de Venda  \
# 0  57302-605            GASOLINA     2021-11-01           6.799
# 1  57302-605              ETANOL     2021-11-01           5.299
# 2  57302-605              DIESEL     2021-11-01           5.549
# 3  57302-605  GASOLINA ADITIVADA     2021-11-01           6.899
# 4  57302-605          DIESEL S10     2021-11-01           5.649
#
#    Valor de Compra Unidade de Medida       Bandeira
# 0              NaN        R$ / litro  VIBRA ENERGIA
# 1              NaN        R$ / litro  VIBRA ENERGIA
# 2              NaN        R$ / litro  VIBRA ENERGIA
# 3              NaN        R$ / litro  VIBRA ENERGIA
# 4              NaN        R$ / litro  VIBRA ENERGIA

# %%
# Quero, na verdade, exibir as primeiras 15 linhas
display(gas_df.head(15))
# Out:
#    Regiao - Sigla Estado - Sigla        Municipio  \
# 0              NE             AL        ARAPIRACA
# 1              NE             AL        ARAPIRACA
# 2              NE             AL        ARAPIRACA
# 3              NE             AL        ARAPIRACA
# 4              NE             AL        ARAPIRACA
# 5              NE             AL  DELMIRO GOUVEIA
# 6              NE             AL  DELMIRO GOUVEIA
# 7              NE             AL  DELMIRO GOUVEIA
# 8              NE             AL  DELMIRO GOUVEIA
# 9              NE             AL  DELMIRO GOUVEIA
# 10             NE             AL  DELMIRO GOUVEIA
# 11             NE             AL  DELMIRO GOUVEIA
# 12             NE             AL  DELMIRO GOUVEIA
# 13             NE             AL  DELMIRO GOUVEIA
# 14             NE             AL  DELMIRO GOUVEIA
#
#                                   Revenda      CNPJ da Revenda  \
# 0                    POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 1                    POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 2                    POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 3                    POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 4                    POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 5          AUTO POSTO FREITAS & MAIA LTDA   12.436.978/0001-80
# 6          AUTO POSTO FREITAS & MAIA LTDA   12.436.978/0001-80
# 7          AUTO POSTO FREITAS & MAIA LTDA   12.436.978/0001-80
# 8          AUTO POSTO FREITAS & MAIA LTDA   12.436.978/0001-80
# 9          AUTO POSTO FREITAS & MAIA LTDA   12.436.978/0001-80
# 10               AUTO POSTO DA PEDRA LTDA   05.518.639/0001-87
# 11               AUTO POSTO DA PEDRA LTDA   05.518.639/0001-87
# 12               AUTO POSTO DA PEDRA LTDA   05.518.639/0001-87
# 13               AUTO POSTO DA PEDRA LTDA   05.518.639/0001-87
# 14  COMERCIO DE COMBUSTIVEIS NENZITA LTDA   04.431.113/0001-00
#
#              Nome da Rua Numero Rua Complemento       Bairro        Cep  \
# 0         RODOVIA AL 220        105       KM 68  CANAFISTULA  57302-605
# 1         RODOVIA AL 220        105       KM 68  CANAFISTULA  57302-605
# 2         RODOVIA AL 220        105       KM 68  CANAFISTULA  57302-605
# 3         RODOVIA AL 220        105       KM 68  CANAFISTULA  57302-605
# 4         RODOVIA AL 220        105       KM 68  CANAFISTULA  57302-605
# 5   RUA FLORIANO PEIXOTO        247         NaN       CENTRO  57480-000
# 6   RUA FLORIANO PEIXOTO        247         NaN       CENTRO  57480-000
# 7   RUA FLORIANO PEIXOTO        247         NaN       CENTRO  57480-000
# 8   RUA FLORIANO PEIXOTO        247         NaN       CENTRO  57480-000
# 9   RUA FLORIANO PEIXOTO        247         NaN       CENTRO  57480-000
# 10  RUA FLORIANO PEIXOTO        281         NaN       CENTRO  57480-000
# 11  RUA FLORIANO PEIXOTO        281         NaN       CENTRO  57480-000
# 12  RUA FLORIANO PEIXOTO        281         NaN       CENTRO  57480-000
# 13  RUA FLORIANO PEIXOTO        281         NaN       CENTRO  57480-000
# 14       AVENIDA CAXANGA        126         NaN  PEDRA VELHA  57480-000
#
#                Produto Data da Coleta  Valor de Venda  Valor de Compra  \
# 0             GASOLINA     2021-11-01           6.799              NaN
# 1               ETANOL     2021-11-01           5.299              NaN
# 2               DIESEL     2021-11-01           5.549              NaN
# 3   GASOLINA ADITIVADA     2021-11-01           6.899              NaN
# 4           DIESEL S10     2021-11-01           5.649              NaN
# 5             GASOLINA     2021-11-01           7.198              NaN
# 6               ETANOL     2021-11-01           5.982              NaN
# 7               DIESEL     2021-11-01           5.974              NaN
# 8   GASOLINA ADITIVADA     2021-11-01           7.208              NaN
# 9           DIESEL S10     2021-11-01           5.983              NaN
# 10            GASOLINA     2021-11-01           7.197              NaN
# 11              ETANOL     2021-11-01           5.987              NaN
# 12              DIESEL     2021-11-01           5.978              NaN
# 13          DIESEL S10     2021-11-01           5.989              NaN
# 14            GASOLINA     2021-11-01           7.175              NaN
#
#    Unidade de Medida       Bandeira
# 0         R$ / litro  VIBRA ENERGIA
# 1         R$ / litro  VIBRA ENERGIA
# 2         R$ / litro  VIBRA ENERGIA
# 3         R$ / litro  VIBRA ENERGIA
# 4         R$ / litro  VIBRA ENERGIA
# 5         R$ / litro  VIBRA ENERGIA
# 6         R$ / litro  VIBRA ENERGIA
# 7         R$ / litro  VIBRA ENERGIA
# 8         R$ / litro  VIBRA ENERGIA
# 9         R$ / litro  VIBRA ENERGIA
# 10        R$ / litro         BRANCA
# 11        R$ / litro         BRANCA
# 12        R$ / litro         BRANCA
# 13        R$ / litro         BRANCA
# 14        R$ / litro         BRANCA

# %%
# Quais são as colunas e que tipo de dados cada um tem...
print(gas_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168409 entries, 0 to 168408
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     168409 non-null  object
#  1   Estado - Sigla     168409 non-null  object
#  2   Municipio          168409 non-null  object
#  3   Revenda            168409 non-null  object
#  4   CNPJ da Revenda    168409 non-null  object
#  5   Nome da Rua        168409 non-null  object
#  6   Numero Rua         168353 non-null  object
#  7   Complemento        35057 non-null   object
#  8   Bairro             168043 non-null  object
#  9   Cep                168409 non-null  object
#  10  Produto            168409 non-null  object
#  11  Data da Coleta     168409 non-null  datetime64[ns]
#  12  Valor de Venda     168409 non-null  float64
#  13  Valor de Compra    0 non-null       float64
#  14  Unidade de Medida  168409 non-null  object
#  15  Bandeira           168409 non-null  object
# dtypes: datetime64[ns](1), float64(2), object(13)
# memory usage: 20.6+ MB
# None

# %%
# Aqui criamos um novo dataframe apenas com as colunas que eu quero..
ca_df = gas_df[['Revenda', 'Municipio', 'Valor de Venda']] 
display(ca_df)
# Out:
#                                            Revenda  Municipio  Valor de Venda
# 0                             POSTO ARAPIRACA LTDA  ARAPIRACA           6.799
# 1                             POSTO ARAPIRACA LTDA  ARAPIRACA           5.299
# 2                             POSTO ARAPIRACA LTDA  ARAPIRACA           5.549
# 3                             POSTO ARAPIRACA LTDA  ARAPIRACA           6.899
# 4                             POSTO ARAPIRACA LTDA  ARAPIRACA           5.649
# ...                                            ...        ...             ...
# 168404  COMERCIAL DE COMBUSTIVEL CACHOEIRINHA LTDA     JEQUIE           5.859
# 168405           ABC DISTRIBUICAO DE PETROLEO LTDA  ITUIUTABA           6.580
# 168406           ABC DISTRIBUICAO DE PETROLEO LTDA  ITUIUTABA           4.740
# 168407           ABC DISTRIBUICAO DE PETROLEO LTDA  ITUIUTABA           5.448
# 168408           ABC DISTRIBUICAO DE PETROLEO LTDA  ITUIUTABA           6.580
#
# [168409 rows x 3 columns]

# %%
# Exibe a 4a. linha.
display(ca_df.loc[3])
# Out:
# Revenda           POSTO ARAPIRACA LTDA
# Municipio                    ARAPIRACA
# Valor de Venda                   6.899
# Name: 3, dtype: object

# %%
# Exibir da 10a. linha até a 20a.linha
display(ca_df.loc[9:19])
# Out:
#                                   Revenda        Municipio  Valor de Venda
# 9          AUTO POSTO FREITAS & MAIA LTDA  DELMIRO GOUVEIA           5.983
# 10               AUTO POSTO DA PEDRA LTDA  DELMIRO GOUVEIA           7.197
# 11               AUTO POSTO DA PEDRA LTDA  DELMIRO GOUVEIA           5.987
# 12               AUTO POSTO DA PEDRA LTDA  DELMIRO GOUVEIA           5.978
# 13               AUTO POSTO DA PEDRA LTDA  DELMIRO GOUVEIA           5.989
# 14  COMERCIO DE COMBUSTIVEIS NENZITA LTDA  DELMIRO GOUVEIA           7.175
# 15  COMERCIO DE COMBUSTIVEIS NENZITA LTDA  DELMIRO GOUVEIA           5.930
# 16  COMERCIO DE COMBUSTIVEIS NENZITA LTDA  DELMIRO GOUVEIA           5.955
# 17  COMERCIO DE COMBUSTIVEIS NENZITA LTDA  DELMIRO GOUVEIA           7.175
# 18  COMERCIO DE COMBUSTIVEIS NENZITA LTDA  DELMIRO GOUVEIA           5.980
# 19         MARCOS ANTONIO DA SILVA CABRAL      ITACOATIARA           6.990

# %%
# Criar um dataframe gas_df contendo 
# apenas as 4 colunas (Revenda, Municipio, Produto, Valor de Venda)
# somente com combustível sendo GASOLINA e exibir na tela
gas_df = ca_df.loc[ca_df['Produto'] == 'GASOLINA']
display(gas_df)

display(gas_df['Valor de Venda'].max())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Produto'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-2a46fbc50d18> in <module>
#       2 # apenas as 4 colunas (Revenda, Municipio, Produto, Valor de Venda)
#       3 # somente com combustível sendo GASOLINA e exibir na tela
# ----> 4 gas_df = ca_df.loc[ca_df['Produto'] == 'GASOLINA']
#       5 display(gas_df)
#       6
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Produto'

# %%
#DataFrame.loc[] com múltiplas condições para filtragem
#Quais são os preços, postos que vendem ETANOL na minha cidade (INDAIATUBA) 
#ordenado do menor valor de venda para o maior
etanol_indaiatuba_df = ca_df.loc[(ca_df['Produto'] == 'ETANOL') & (ca_df['Municipio'] == 'INDAIATUBA')]
display(etanol_indaiatuba_df.sort_values(by='Valor de Venda'))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Produto'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-5c95e8a91d04> in <module>
#       2 #Quais são os preços, postos que vendem ETANOL na minha cidade (INDAIATUBA)
#       3 #ordenado do menor valor de venda para o maior
# ----> 4 etanol_indaiatuba_df = ca_df.loc[(ca_df['Produto'] == 'ETANOL') & (ca_df['Municipio'] == 'INDAIATUBA')]
#       5 display(etanol_indaiatuba_df.sort_values(by='Valor de Venda'))
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Produto'

# %%
# Qual a média de preços dos combustíveis GASOLINA e GASOLINA ADITIVADA do Bairro MOOCA em SÃO PAULO?
display(gas_df.loc[(gas_df['Bairro'] == 'MOOCA') & 
                            (gas_df['Municipio'] == 'SAO PAULO') & 
                            ((gas_df['Produto'] == 'GASOLINA') | (gas_df['Produto'] == 'GASOLINA ADITIVADA')), 
                            ['Valor de Venda']].mean())
# Out:
# Valor de Venda    6.575596
# dtype: float64

# %%
# Como mostrar média de valor de venda POR COMBUSTÍVEL Brasil todo?
media_por_combustivel_df = ca_df[['Produto', 'Valor de Venda']].groupby(by='Produto').mean().round(2)
display(media_por_combustivel_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-f4e8565018c2> in <module>
#       1 # Como mostrar média de valor de venda POR COMBUSTÍVEL Brasil todo?
# ----> 2 media_por_combustivel_df = ca_df[['Produto', 'Valor de Venda']].groupby(by='Produto').mean().round(2)
#       3 display(media_por_combustivel_df)
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 1377             raise KeyError(f"{not_found} not in index")
#    1378
#    1379
#
# KeyError: "['Produto'] not in index"

# %%
#Quero adicionar uma coluna de valor booleano no combustiveis_df
# chamada "Ativo" que, por padrão, vai ser True para 
# TODAS as linhas
gas_df['Ativo'] = True
print(gas_df.info())
display(gas_df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168409 entries, 0 to 168408
# Data columns (total 17 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     168409 non-null  object
#  1   Estado - Sigla     168409 non-null  object
#  2   Municipio          168409 non-null  object
#  3   Revenda            168409 non-null  object
#  4   CNPJ da Revenda    168409 non-null  object
#  5   Nome da Rua        168409 non-null  object
#  6   Numero Rua         168353 non-null  object
#  7   Complemento        35057 non-null   object
#  8   Bairro             168043 non-null  object
#  9   Cep                168409 non-null  object
#  10  Produto            168409 non-null  object
#  11  Data da Coleta     168409 non-null  datetime64[ns]
#  12  Valor de Venda     168409 non-null  float64
#  13  Valor de Compra    0 non-null       float64
#  14  Unidade de Medida  168409 non-null  object
#  15  Bandeira           168409 non-null  object
#  16  Ativo              168409 non-null  bool
# dtypes: bool(1), datetime64[ns](1), float64(2), object(13)
# memory usage: 20.7+ MB
# None
#   Regiao - Sigla Estado - Sigla  Municipio               Revenda  \
# 0             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 1             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 2             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 3             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 4             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
#
#        CNPJ da Revenda     Nome da Rua Numero Rua Complemento       Bairro  \
# 0   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 1   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 2   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 3   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 4   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
#
#          Cep             Produto Data da Coleta  Valor de Venda  \
# 0  57302-605            GASOLINA     2021-11-01           6.799
# 1  57302-605              ETANOL     2021-11-01           5.299
# 2  57302-605              DIESEL     2021-11-01           5.549
# 3  57302-605  GASOLINA ADITIVADA     2021-11-01           6.899
# 4  57302-605          DIESEL S10     2021-11-01           5.649
#
#    Valor de Compra Unidade de Medida       Bandeira  Ativo
# 0              NaN        R$ / litro  VIBRA ENERGIA   True
# 1              NaN        R$ / litro  VIBRA ENERGIA   True
# 2              NaN        R$ / litro  VIBRA ENERGIA   True
# 3              NaN        R$ / litro  VIBRA ENERGIA   True
# 4              NaN        R$ / litro  VIBRA ENERGIA   True

# %%
# Exportar para Excel o dataframe com etanol em Indaiatuba....
etanol_indaiatuba_df.to_excel('etanol_indaiatuba.xlsx', sheet_name='Etanol em Indaiatuba')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-067dacb5b0bb> in <module>
#       1 # Exportar para Excel o dataframe com etanol em Indaiatuba....
# ----> 2 etanol_indaiatuba_df.to_excel('etanol_indaiatuba.xlsx', sheet_name='Etanol em Indaiatuba')
#
# NameError: name 'etanol_indaiatuba_df' is not defined
